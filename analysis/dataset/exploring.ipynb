# %%
import pandas as pd

# %%
df_btc = pd.read_csv('onchain_data_btc.csv')

# %%
df_btc
# Out:
#           high       low      open  volumefrom      volumeto     close  \
# 0      9025.73   8804.20   8823.46    61895.95  5.538923e+08   8968.25
# 1      9741.91   8957.68   8967.86   136352.05  1.276465e+09   9655.77
# 2      9765.23   8757.06   9657.69   192797.41  1.779806e+09   8873.62
# 3      9315.13   8669.38   8873.57   111690.32  9.974279e+08   9282.12
# 4      9385.87   8923.48   9289.01    82025.40  7.581824e+08   8938.47
# ...        ...       ...       ...         ...           ...       ...
# 1992  28105.36  27714.35  27973.69     8547.03  2.386900e+08  27933.57
# 1993  27999.80  27282.89  27933.57    21887.87  6.039641e+08  27598.77
# 1994  27735.72  27298.50  27598.77    18600.95  5.111095e+08  27395.40
# 1995  27475.69  26531.55  27395.40    30496.51  8.213956e+08  26871.21
# 1996  26937.98  26549.78  26871.21    16400.37  4.385320e+08  26756.23
#
#             date      id symbol  zero_balance_addresses_all_time  ...  \
# ...

# %%
df_btc.columns
# Out:
# Index(['high', 'low', 'open', 'volumefrom', 'volumeto', 'close', 'date', 'id',
#        'symbol', 'zero_balance_addresses_all_time',
#        'unique_addresses_all_time', 'new_addresses', 'active_addresses',
#        'transaction_count', 'transaction_count_all_time',
#        'large_transaction_count', 'average_transaction_value', 'block_height',
#        'hashrate', 'difficulty', 'block_time', 'block_size', 'current_supply'],
#       dtype='object')
